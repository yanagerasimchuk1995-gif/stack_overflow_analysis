# %%
import pandas as pd
df = pd.read_csv('survey_results_public.csv')
schema = pd.read_csv('survey_results_schema.csv')
pd.set_option('display.max_columns', None)
df
# Out:
# C:\Users\User7\AppData\Local\Temp\ipykernel_17576\1521319461.py:2: DtypeWarning: Columns (56,74,92,97,98,105,109,110,132,162,165) have mixed types. Specify dtype option on import or set low_memory=False.
#   df = pd.read_csv('survey_results_public.csv')
#        ResponseId                                         MainBranch  \
# 0               1                     I am a developer by profession
# 1               2                     I am a developer by profession
# 2               3                     I am a developer by profession
# 3               4                     I am a developer by profession
# 4               5                     I am a developer by profession
# ...           ...                                                ...
# 49186       49187                        I code primarily as a hobby
# 49187       49188                     I am a developer by profession
# 49188       49189                     I am a developer by profession
# ...

# %%
schema
# Out:
#         qid            qname  \
# 0     QID18    TechEndorse_1
# 1     QID18    TechEndorse_2
# 2     QID18    TechEndorse_3
# 3     QID18    TechEndorse_4
# 4     QID18    TechEndorse_5
# ..      ...              ...
# 134  QID103  AIAgentObsWrite
# 135   QID92  AIAgentExternal
# 136  QID104  AIAgentExtWrite
# 137  QID100          AIHuman
# 138   QID93           AIOpen
#
#                                               question type  \
# 0    What attracts you to a technology or causes yo...   RO
# 1    What attracts you to a technology or causes yo...   RO
# 2    What attracts you to a technology or causes yo...   RO
# 3    What attracts you to a technology or causes yo...   RO
# 4    What attracts you to a technology or causes yo...   RO
# ..                                                 ...  ...
# 134  Was the tool or tools for AI agent observabili...   TE
# 135  You indicated you use or develop AI agents as ...   MC
# 136  Was the out-of-the-box agents, copilots or ass...   TE
# ...

# %% [markdown]
# Завдання 1. Підрахунок загальної кількості респондентів

# %%
number_respondents = df['ResponseId'].nunique() # Кількість респондентів (унікальні ResponseId)
print('Загальна кількість респондентів:', number_respondents)
# Out:
# Загальна кількість респондентів: 49191

# %% [markdown]
# Завдання 2. Аналіз повноти відповідей респондентів

# %%
schema_questions = schema["qname"].unique() # Унікальні назви питань зі схеми
df_columns = df.columns # Назви колонок у датасеті відповідей
questions = list(set(schema_questions).intersection(set(df_columns))) # Спільні питання між схемою і датасетом (список)
filtered = df.dropna(subset=questions) # Респонденти без пропусків у вибраних питаннях
print(f'Кількість респондентів, які відповіли на всі запитання: {filtered.shape[0]}\n'
      f'Кількість запитань для перевірки: {len(questions)}')
# Out:
# Кількість респондентів, які відповіли на всі запитання: 0
# Кількість запитань для перевірки: 126

# %% [markdown]
# Завдання 3. Статистичний аналіз досвіду респондентів

# %%
print(f"Міри центральної тенденції:")
print(f"Mean - {round(df['WorkExp'].mean(), 2)}")
print(f"Median - {df['WorkExp'].median()}")
print(f"Mode - {df['WorkExp'].mode()[0]}")
# Out:
# Міри центральної тенденції:
# Mean - 13.37
# Median - 10.0
# Mode - 10.0

# %% [markdown]
# Завдання 4. Аналіз віддаленої роботи

# %%
# Фільтрую респондентів, які працюють повністю віддалено, і рахую їх кількість
count_work_remote = df[df['RemoteWork'] == 'Remote'].shape[0] 
print(f'Кількість респондентів, які працюють віддалено: {count_work_remote}')
# Out:
# Кількість респондентів, які працюють віддалено: 10931

# %% [markdown]
# Завдання 5. Визначення популярності Python

# %%
# Створюю маску: перевіряю чи згадується "Python" у списку мов кожного респондента
worked_with_python = df['LanguageHaveWorkedWith'].str.contains('Python', case=False, na=False)
# Рахую кількість респондентів, які використовують Python (True = 1, False = 0) 
count_worked_with_python = worked_with_python.sum() 
# Відсоток респондентів, які використовують Python
percent = round(count_worked_with_python/number_respondents*100, 2)
print(f'Відсоток респондентів, які програмують на Python: {percent}%')
# Out:
# Відсоток респондентів, які програмують на Python: 37.54%

# %% [markdown]
#  Завдання 6. Аналіз шляхів навчання програмуванню

# %%
# Перевіряю чи використовував респондент онлайн курси для навчання
learned_with_online_courses = df['LearnCode'].str.contains('online courses', case=False, na=False)
# Рахую кількість респондентів, які навчались онлайн
count_learned_with_online_courses = learned_with_online_courses.sum()
print(f'Кількість респондентів, які навчалися програмувати через онлайн курси: {count_learned_with_online_courses}')
# Out:
# Кількість респондентів, які навчалися програмувати через онлайн курси: 10973

# %% [markdown]
# Завдання 7. Географічний аналіз компенсації Python-розробників

# %%
# Вибираю рядки ресондентів з мовою програмування Python
df_worked_with_python = df[df['LanguageHaveWorkedWith'].str.contains('Python', case=False, na=False)]
# Видаляю рядки, де відсутнє значення зарплати
df_worked_with_python = df_worked_with_python.dropna(subset=['ConvertedCompYearly'])
# Групую за країною і обчислюю середнє значення і медіану зарплати
py_progers_by_country = (df_worked_with_python.groupby('Country').
    agg(Mean_ConvertedCompYearly=('ConvertedCompYearly', 'mean'), Median_ConvertedCompYearly=('ConvertedCompYearly', 'median')).reset_index())
# Округлюю середнє значення до двох знаків після коми
py_progers_by_country['Mean_ConvertedCompYearly'] = round(py_progers_by_country['Mean_ConvertedCompYearly'], 2)
py_progers_by_country
# Out:
#                                   Country  Mean_ConvertedCompYearly  \
# 0                             Afghanistan                  22328.67
# 1                                 Albania                  47217.60
# 2                                 Algeria                  20187.29
# 3                                 Andorra                 226103.50
# 4                     Antigua and Barbuda                      1.00
# ..                                    ...                       ...
# 148  Venezuela, Bolivarian Republic of...                   9908.65
# 149                              Viet Nam                 218837.17
# 150                                 Yemen                  32929.50
# 151                                Zambia                   5424.25
# 152                              Zimbabwe                  34000.00
#
#      Median_ConvertedCompYearly
# 0                        1000.0
# 1                       50000.0
# 2                        7088.0
# ...

# %% [markdown]
# Завдання 8. Аналіз освіти найбільш оплачуваних спеціалістів

# %%
# Обираю потрібні колонки даних, видаляю пропуски в заробітній платі, сортую по заробітній платі за спаданням і беру топ-5
df1 = (df[['ResponseId', 'EdLevel', 'ConvertedCompYearly']].
    dropna(subset=['ConvertedCompYearly']).
    sort_values(by='ConvertedCompYearly', ascending=False).
    reset_index(drop=True).
    head(5)
      )
df1
# Out:
#    ResponseId                                          EdLevel  \
# 0       34268              Associate degree (A.A., A.S., etc.)
# 1       28701  Master’s degree (M.A., M.S., M.Eng., MBA, etc.)
# 2       43144              Associate degree (A.A., A.S., etc.)
# 3       35354     Bachelor’s degree (B.A., B.S., B.Eng., etc.)
# 4       45972  Master’s degree (M.A., M.S., M.Eng., MBA, etc.)
#
#    ConvertedCompYearly
# 0           50000000.0
# 1           33552715.0
# 2           18387548.0
# 3           15430267.0
# 4           13921760.0

# %% [markdown]
# *Завдання 9. Аналіз популярності Python по віковим категоріям

# %%
# Перевіряю чи згадується "Python" у списку мов кожного респондента і додаю колонку з булевим типом даних
df['worked_with_python'] = df['LanguageHaveWorkedWith'].str.contains('Python', case=False, na=False)
# Рахую частку респондентів в кожній віковій групі, які програмують на Python
result = df.groupby('Age')['worked_with_python'].mean().reset_index(name='Python_Percent')
result['Python_Percent'] = (result['Python_Percent']*100).round(2)
result
# Out:
#                  Age  Python_Percent
# 0    18-24 years old           40.00
# 1    25-34 years old           36.94
# 2    35-44 years old           36.72
# 3    45-54 years old           38.63
# 4    55-64 years old           37.24
# 5  65 years or older           31.63
# 6  Prefer not to say           31.22

# %% [markdown]
# *Завдання 10. Аналіз індустрій серед високооплачуваних віддалених працівників

# %%
# Обчислюю 75-й перцентиль річної зарплати
percentile_75 = df['ConvertedCompYearly'].quantile(0.75)
# Фільтрую дані за двома критеріями: зарплатою вище 75-го перцентиля та віддаленою роботою
df_filtered = df[(df['ConvertedCompYearly'] > percentile_75) & (df['RemoteWork'] == 'Remote')]
# Визначаю найпоширеніші індустрії серед високооплачуваних віддалених працівників
top_industry = df_filtered['Industry'].value_counts().reset_index(name='Count')
top_industry
# Out:
#                                       Industry  Count
# 0                         Software Development   1186
# 1                                      Fintech    190
# 2                                   Healthcare    188
# 3                                       Other:    176
# 4   Internet, Telecomm or Information Services    138
# 5                   Banking/Financial Services     88
# 6                                   Government     78
# 7                 Media & Advertising Services     75
# 8                 Retail and Consumer Services     65
# 9              Transportation, or Supply Chain     63
# 10        Computer Systems Design and Services     59
# 11                                   Insurance     46
# 12                                      Energy     45
# 13                               Manufacturing     33
# 14                            Higher Education     30
